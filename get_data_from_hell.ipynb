# %%
#訓練目標
company_list = ['CASH.O', 'MSTR.O', 'MSEX.O', 'MOFG.O', 'MOBL.O', 'MCRI.O', 'OMER.O', 'OSPN.O', 'BIOS.O', 'OPB.O', 'OSUR.O', 'QTRX.O', 'RARX.O', 'RAVN.O', 'RECN.O', 'ROIC.O', 'RTRX.O', 'RVNC.O', 'RCKT.O', 'STBA.O', 'SAFT.O', 'STAA.O', 'USCR.O', 'UCTT.O', 'UCFC.O', 'UCBI.O', 'AMAG.O', 'CCRN.O', 'CBAY.O', 'DMRC.O', 'DLTH.O', 'DVAX.O', 'EGAN.O', 'ELGX.O', 'WATT.O', 'ERII.O', 'FRGI.O', 'FTR.O', 'GNMK.O', 'RDI.O', 'SCWX.O', 'CENTA.O', 'DISCB.O', 'DISCK.O', 'DGICB.O', 'ESGRO.O', 'ESGRP.O', 'FITBO.O', 'MBINO.O', 'NYMTP.O', 'RDIB.O', 'RUSHA.O', 'TCFCP.O', 'TCBIP.O', 'TSCBP.O', 'CELG.O^K19', 'VIAB.O^L19', 'WFM.O^H17', 'ALOG.O^F18', 'APOL.O^B17', 'CALD.O^D18', 'ABCD.O^L18', 'CBF.O^L17', 'CLWR.O^G13', 'CSBK.O^D18', 'CHUBA.O^E18', 'DELL.O^J13', 'DOVA.O^K19', 'EFII.O^G19', 'IDTI.O^D19', 'ISIL.O^B17', 'ISLE.O^E17', 'IXYS.O^A18', 'JUNO.O^C18', 'KTWO.O^K18', 'LIFE.O^B14', 'LOXO.O^B19', 'MDVN.O^I16', 'PNK.O^J18', 'PMCS.O^A16', 'PLCM.O^I16', 'WFBI.O^A18', 'WEB.O^J18', 'LVNTA.O^C18', 'LVNAR.O^J12', 'LVNTB.O^C18', 'MBFIO.O^C19', 'SRRR.O^D09', 'DWMT.O^L10', 'MNNY.O^C11', 'MOLXA.O^L13', 'ESTX.O^D10', 'JPM', 'JNJ', 'WMT', 'BAC', 'DIS', 'CVX', 'MRK', 'PFE', 'BA', 'C', 'ORCL.K', 'MCD', 'MDT', 'DY', 'CRM', 'PE', 'ABBV.K', 'TMO', 'HON', 'GE', 'AXP', 'BLK', 'TGT', 'ECL', 'EW', 'EL', 'HCA', 'INFO.K', 'ZBH', 'ETR', 'FRC', 'HSY', 'NR', 'PXD', 'SWK', 'VTR', 'RMD', 'VEEV.K', 'WY', 'AGR', 'MLM', 'AJG', 'KMX', 'CAG', 'DRI', 'EFX', 'MRO', 'MGM', 'NUE', 'WRB', 'WAB', 'WAT', 'WCG', 'AAP', 'ATO', 'CNP', 'FNF', 'BEN', 'HST', 'SJM', 'RE', 'FICO.K', 'NNN', 'NLSN.K', 'OGE', 'OC', 'PKI', 'PNW', 'SR', 'STOR.K', 'FTI', 'TR', 'UGI', 'USFD.K', 'VER', 'WEX', 'XRX', 'AA', 'AEO', 'ATH', 'AXTA.K', 'CWK', 'EHC', 'GGG', 'HOG', 'HEI', 'HLF', 'HXL', 'HUBB.K', 'HUBS.K', 'H', 'IVZ', 'KBH', 'LEA', 'MOH', 'NRZ', 'CHGG.K', 'CC', 'CHK', 'CIM', 'CIT', 'CLH', 'CLDR.K', 'CBU', 'CTB', 'CPA', 'CLGX.K', 'COR', 'EQC', 'ESNT.K', 'FND', 'FLO', 'FLS', 'FNB', 'FCN', 'GATX.K', 'GNRC.K', 'GWR', 'GHC', 'GPK', 'GRUB.K', 'GES', 'HAE', 'HBI', 'THG', 'HE', 'HR', 'HP', 'IDA', 'NGVT.K', 'MSM', 'MUSA.K', 'NFG', 'NHI', 'NCR', 'NEWR.K', 'SNR', 'NEU', 'DOC', 'PDM', 'SEM', 'SCS', 'TDOC.K', 'AIR', 'LKSD.K', 'APC^H19', 'WP^G19', 'GAS^G16', 'ARG^E16', 'CCP^H17', 'CFN^C15', 'CIVI.K^C19', 'MYCC.K^I17', 'DNB^B19', 'DFT^I17', 'EDR^I18', 'KCI^K11', 'OMX^K13', 'SOV^A09', 'SE^B17', 'TRK^I19', 'BDC_pb^G19', 'BAC_pd^I18', 'BAC_pi^G18', 'GLG_u^J10', 'GS_pb^H19', 'HEK_u^K11', 'HSH_w^F12', 'HPT_pb^B12', 'HUBa^L15', 'JPM_pb^C19', 'JPM_pa^L19', 'KMI_pa^J18', 'LMI^G11', 'ULTA.O', 'LKQ.O', 'PFG.O', 'FFIV.O', 'FSLR.O', 'FIVE.O', 'GLIBA.O', 'GNTX.O', 'GT.O', 'MASI.O', 'PNFP.O', 'POOL.O', 'PRAH.O', 'SRCL.O', 'TCF.O', 'URBN.O', 'WWD.O', 'ACHC.O', 'XLRN.O', 'AEIS.O', 'CMPR.O', 'CRUS.O', 'IART.O', 'IBKR.O', 'IRDM.O', 'TECD.O', 'TERP.O', 'TTEK.O', 'TXRH.O', 'SMPL.O', 'UBSI.O', 'RYTM.O', 'DGICA.O', 'PRPL.O', 'QADB.O', 'RBB.O', 'BPYPP.O', 'CBSHP.O', 'LTRPB.O', 'NTRSO.O', 'QADA.O', 'QRTEB.O', 'SNHNI.O', 'Z.O', 'CPLA.O^H18', 'CBLK.O^J19', 'CHSI.O^G12', 'CAVM.O^G18', 'CEPH.O^J11', 'COBZ.O^J18', 'CTRL.O^H19', 'CRAY.O^I19', 'CTCM.O^E16', 'CUNB.O^J17', 'DTV.O^G15', 'DWA.O^H16', 'ESIO.O^B19', 'EMCI.O^I19', 'LERA.O^C09', 'HPE', 'KR', 'CPB', 'TXT', 'FR', 'FUL', 'GTES.K', 'NVRO.K', 'NJR', 'NYCB.K', 'NYT', 'ZNGA.O', 'AAON.O', 'CPHD.O^K16']

# %%
import numpy as np
import pandas as pd
import talib
import datetime as datetime
import pandas_datareader as pdr
import pandas as pd
import os

# %%
start = datetime.datetime(2013,1,1)
end = datetime.datetime(2020,12,30)

# %%
error_company = []
complete_company = []
for company in company_list:
    try:
        if '.O' in company:
            company = company.split('.')[0]
            print(company)
        df = pdr.DataReader(company ,'yahoo', start=start, end =end)
        df.to_csv('./many_csv/'+company+'.csv')
        complete_company.append(company)
        print(company+" done!")
    except:
        error_company.append(company) 
        print(company+" fail!")
# Out:
# CASH
# CASH done!
# MSTR
# MSTR done!
# MSEX
# MSEX done!
# MOFG
# MOFG done!
# MOBL
# MOBL done!
# MCRI
# MCRI done!
# OMER
# OMER done!
# OSPN
# OSPN done!
# BIOS
# BIOS fail!
# OPB
# OPB fail!
# OSUR
# OSUR done!
# QTRX
# QTRX done!
# RARX
# RARX fail!
# RAVN
# RAVN done!
# RECN
# RECN fail!
# ROIC
# ROIC done!
# RTRX
# RTRX done!
# RVNC
# RVNC done!
# RCKT
# RCKT done!
# STBA
# STBA done!
# SAFT
# SAFT done!
# STAA
# STAA done!
# USCR
# USCR done!
# UCTT
# UCTT done!
# UCFC
# UCFC fail!
# UCBI
# UCBI done!
# AMAG
# AMAG done!
# CCRN
# CCRN done!
# CBAY
# CBAY done!
# DMRC
# DMRC done!
# DLTH
# DLTH done!
# DVAX
# DVAX done!
# EGAN
# EGAN done!
# ELGX
# ELGX done!
# WATT
# WATT done!
# ERII
# ERII done!
# FRGI
# FRGI done!
# FTR
# FTR fail!
# GNMK
# GNMK done!
# RDI
# RDI done!
# SCWX
# SCWX done!
# CENTA
# CENTA done!
# DISCB
# DISCB done!
# DISCK
# DISCK done!
# DGICB
# DGICB done!
# ESGRO
# ESGRO done!
# ESGRP
# ESGRP done!
# FITBO
# FITBO done!
# MBINO
# MBINO done!
# NYMTP
# ...

# %%
print(len(error_company))
print(len(company_list))
print(len(complete_company))
complete_company
# Out:
# 98
# 339
# 241
# ['CASH',
#  'MSTR',
#  'MSEX',
#  'MOFG',
#  'MOBL',
#  'MCRI',
#  'OMER',
#  'OSPN',
#  'OSUR',
#  'QTRX',
#  'RAVN',
#  'ROIC',
#  'RTRX',
#  'RVNC',
#  'RCKT',
#  'STBA',
#  'SAFT',
#  'STAA',
#  'USCR',
#  'UCTT',
#  'UCBI',
#  'AMAG',
#  'CCRN',
#  'CBAY',
#  'DMRC',
#  'DLTH',
#  'DVAX',
#  'EGAN',
#  'ELGX',
#  'WATT',
#  'ERII',
#  'FRGI',
#  'GNMK',
#  'RDI',
#  'SCWX',
#  'CENTA',
#  'DISCB',
#  'DISCK',
#  'DGICB',
#  'ESGRO',
#  'ESGRP',
#  'FITBO',
#  'MBINO',
#  'NYMTP',
#  'RDIB',
#  'RUSHA',
#  'TCFCP',
#  'TCBIP',
#  'TSCBP',
#  'ALOG',
#  'CALD',
#  'ABCD',
#  'CLWR',
#  'CSBK',
#  'CHUBA',
#  'DELL',
#  'IDTI',
#  'JUNO',
#  'KTWO',
#  'LIFE',
#  'PNK',
#  'WEB',
#  'LVNTB',
#  'MOLXA',
#  'JPM',
#  'JNJ',
#  'WMT',
#  'BAC',
#  'DIS',
#  'CVX',
#  'MRK',
#  'PFE',
#  'BA',
#  'C',
#  'MCD',
#  'MDT',
#  'DY',
#  'CRM',
#  'PE',
#  'TMO',
#  'HON',
#  'GE',
#  'AXP',
#  'BLK',
#  'TGT',
#  'ECL',
#  'EW',
#  'EL',
#  'HCA',
#  'ZBH',
#  'ETR',
# ...

# %% [markdown]
# #對找得到價位者 做資料搜集

# %%
quater_data = pd.read_csv('./2003-2020財報資料_quarter.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',100)
# quater_data = quater_data.fillna(0)
quater_data.head()
# Out:
#     gvkey  permno       adate     qdate  public_date    CAPEI     bm  \
# 0  126554   87432  20021031.0  20030131     20030331  270.229  0.560
# 1  126554   87432  20021031.0  20030430     20030630 -372.840  0.557
# 2  126554   87432  20021031.0  20030731     20030930  -73.934  0.263
# 3  126554   87432  20031031.0  20031031     20031231  -35.717  0.238
# 4  126554   87432  20031031.0  20040131     20040331  -45.610  0.173
#
#         evm  pe_op_basic  pe_op_dil  pe_exi  pe_inc     ps      pcf  dpr  \
# 0   -26.495      -11.535    -11.535  -7.429  -5.644  1.033  -13.129  NaN
# 1   -25.033      -28.750    -28.750 -12.695  -9.354  1.534  -17.031  NaN
# 2   -66.435       -6.761     -6.761  -5.106  -4.512  1.719  -20.375  NaN
# 3  1445.770       -9.878     -9.878  -7.735  -6.722  2.299  -96.685  NaN
# 4    37.604      -12.212    -12.212  -9.330  -9.249  2.419 -211.700  NaN
#
#      npm  opmbd  opmad    gpm   ptpm    cfm    roa    roe   roce  efftax  \
# ...

# %%
quater_data.reset_index(inplace=True)
quater_data.set_index("index" , inplace=True)

# %%
quater_data.head()
# Out:
#         gvkey  permno       adate     qdate  public_date    CAPEI     bm  \
# index
# 0      126554   87432  20021031.0  20030131     20030331  270.229  0.560
# 1      126554   87432  20021031.0  20030430     20030630 -372.840  0.557
# 2      126554   87432  20021031.0  20030731     20030930  -73.934  0.263
# 3      126554   87432  20031031.0  20031031     20031231  -35.717  0.238
# 4      126554   87432  20031031.0  20040131     20040331  -45.610  0.173
#
#             evm  pe_op_basic  pe_op_dil  pe_exi  pe_inc     ps      pcf  dpr  \
# index
# 0       -26.495      -11.535    -11.535  -7.429  -5.644  1.033  -13.129  NaN
# 1       -25.033      -28.750    -28.750 -12.695  -9.354  1.534  -17.031  NaN
# 2       -66.435       -6.761     -6.761  -5.106  -4.512  1.719  -20.375  NaN
# 3      1445.770       -9.878     -9.878  -7.735  -6.722  2.299  -96.685  NaN
# 4        37.604      -12.212    -12.212  -9.330  -9.249  2.419 -211.700  NaN
#
# ...

# %%
train_data_clip = pd.DataFrame()
for i in complete_company:
    flag = 0 
    start_ind = 0
    end_ind = 0 
    for ind , j in  enumerate(quater_data['TICKER']):
        if str(i) in str(j) and flag ==0 :
            flag = 1
            start_ind =ind
        elif str(i) not in str(j) and flag == 1:
            end_ind =  ind
            break
    if flag ==1:
        y = quater_data[start_ind:end_ind]
        train_data_clip = pd.concat([train_data_clip ,y], axis=0)
    print(i+" done!", start_ind ,end_ind)
# Out:
# CASH done! 40149 40217
# MSTR done! 159234 159302
# MSEX done! 158444 158512
# MOFG done! 155907 155954
# MOBL done! 155651 155673
# MCRI done! 148588 148656
# OMER done! 175759 175799
# OSPN done! 178852 178858
# OSUR done! 178975 179043
# QTRX done! 197605 197613
# RAVN done! 198511 198579
# ROIC done! 0 0
# RTRX done! 206641 206664
# RVNC done! 207088 207111
# RCKT done! 199232 199239
# STBA done! 223808 223876
# SAFT done! 207942 208010
# STAA done! 223630 223698
# USCR done! 247328 247363
# UCTT done! 244034 244097
# UCBI done! 243828 243896
# AMAG done! 11412 11466
# CCRN done! 43460 43528
# CBAY done! 41097 41119
# DMRC done! 71058 71124
# DLTH done! 70732 70748
# DVAX done! 73882 73945
# EGAN done! 77624 77661
# ELGX done! 78602 78670
# WATT done! 255249 255272
# ERII done! 82304 82349
# FRGI done! 95354 95384
# GNMK done! 103131 103169
# RDI done! 17402 17418
# SCWX done! 211272 211287
# CENTA done! 0 0
# DISCB done! 0 0
# DISCK done! 0 0
# DGICB done! 68940 69008
# ...

# %%
train_data_clip.to_csv('./train_lose_label.csv')

# %%
print(complete_company)
# Out:
# ['CASH', 'MSTR', 'MSEX', 'MOFG', 'MOBL', 'MCRI', 'OMER', 'OSPN', 'OSUR', 'QTRX', 'RAVN', 'ROIC', 'RTRX', 'RVNC', 'RCKT', 'STBA', 'SAFT', 'STAA', 'USCR', 'UCTT', 'UCBI', 'AMAG', 'CCRN', 'CBAY', 'DMRC', 'DLTH', 'DVAX', 'EGAN', 'ELGX', 'WATT', 'ERII', 'FRGI', 'GNMK', 'RDI', 'SCWX', 'CENTA', 'DISCB', 'DISCK', 'DGICB', 'ESGRO', 'ESGRP', 'FITBO', 'MBINO', 'NYMTP', 'RDIB', 'RUSHA', 'TCFCP', 'TCBIP', 'TSCBP', 'ALOG', 'CALD', 'ABCD', 'CLWR', 'CSBK', 'CHUBA', 'DELL', 'IDTI', 'JUNO', 'KTWO', 'LIFE', 'PNK', 'WEB', 'LVNTB', 'MOLXA', 'JPM', 'JNJ', 'WMT', 'BAC', 'DIS', 'CVX', 'MRK', 'PFE', 'BA', 'C', 'MCD', 'MDT', 'DY', 'CRM', 'PE', 'TMO', 'HON', 'GE', 'AXP', 'BLK', 'TGT', 'ECL', 'EW', 'EL', 'HCA', 'ZBH', 'ETR', 'FRC', 'HSY', 'NR', 'PXD', 'SWK', 'VTR', 'RMD', 'WY', 'AGR', 'MLM', 'AJG', 'KMX', 'CAG', 'DRI', 'EFX', 'MRO', 'MGM', 'NUE', 'WRB', 'WAB', 'WAT', 'AAP', 'ATO', 'CNP', 'FNF', 'BEN', 'HST', 'SJM', 'RE', 'NNN', 'OGE', 'OC', 'PKI', 'PNW', 'SR', 'FTI', 'TR', 'UGI', 'VER', 'WEX', 'XRX', 'AA', 'AEO
# ...

# %%
len(complete_company)
# Out:
# 241
